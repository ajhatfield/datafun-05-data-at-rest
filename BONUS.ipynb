# %% [markdown]
# # Optional Bonus
#
# ## Author : Alison Hatfield
# ### Date: Sep 2023

# %% [markdown]
# 1. Locate a unique csv dataset.
# 2. Use pandas to import the csv dataset into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('Basketball.csv')
df.head()
# Out:
#      Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0  Team 1          86  4385        2762     1647        552       563
# 1  Team 2          86  4262        2762     1581        573       608
# 2  Team 3          80  3442        2614     1241        598       775
# 3  Team 4          82  3386        2664     1187        616       861
# 4  Team 5          86  3368        2762     1209        633       920
#
#   BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 0         5947        3140                 33        23       1929
# 1         5900        3114                 25        25       1929
# 2         4534        3309                 10         8       1929
# 3         4398        3469                  6         6   1931to32
# 4         4631        3700                  8         7       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# ...

# %% [markdown]
# ## Use the DataFrame commands to clean the data as needed and/or rename the columns.

# %%
df.rename(columns={'Team':'team','Tournament': 'tournaments_played','Score': 'points_scored','PlayedGames':'games_played', 
              'WonGames':'games_won','DrawnGames':'tied_games', 'LostGames':'lost_games', 'BasketScored': 'baskets_scored', 
              'BasketGiven': 'baskets_given', 'TournamentChampion': 'tournaments_won', 'Runner-Up': 'tournaments_second', 
              'TeamLaunch': 'team_launch', 'HighestPositionHeld': 'highest_ranking'}, inplace=True)
df.head()
# Out:
#      team  tournaments_played points_scored games_played games_won tied_games  \
# 0  Team 1                  86          4385         2762      1647        552
# 1  Team 2                  86          4262         2762      1581        573
# 2  Team 3                  80          3442         2614      1241        598
# 3  Team 4                  82          3386         2664      1187        616
# 4  Team 5                  86          3368         2762      1209        633
#
#   lost_games baskets_scored baskets_given tournaments_won Runner-up  \
# 0        563           5947          3140              33        23
# 1        608           5900          3114              25        25
# 2        775           4534          3309              10         8
# 3        861           4398          3469               6         6
# 4        920           4631          3700               8         7
#
#   team_launch  highest_ranking
# 0        1929                1
# ...

# %% [markdown]
# ## Use the DataFrame describe() function to calculate basic descriptive statistics.

# %%
df.describe()
# Out:
#        tournaments_played  highest_ranking
# count           61.000000        61.000000
# mean            24.000000         7.081967
# std             26.827225         5.276663
# min              1.000000         1.000000
# 25%              4.000000         3.000000
# 50%             12.000000         6.000000
# 75%             38.000000        10.000000
# max             86.000000        20.000000

# %% [markdown]
# ## Use the DataFrame hist() function to generate histograms for all numeric columns.

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'tournaments_played'}>,
#         <Axes: title={'center': 'highest_ranking'}>]], dtype=object)
